# %% [markdown]
# # Análisis Exploratorio de Datos de Juzgado 13
#
# ## Primera Instancia - Montos

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import re
import sys
import nltk
sys.path.insert(0, "../data/")
from nltk.tokenize import word_tokenize
from nltk.util import ngrams
from bisect import bisect_left
pd.set_option('display.max_colwidth', -1)
project_dir = Path().resolve().parents[0]

# %% [markdown]
# ## 1. Carga de Datos

# %%
project_dir
# Out:
# PosixPath('/Users/dscgim/git_project_carlos/jusdata_violencia_de_genero')

# %%
ls_terminos = pd.read_excel(str(project_dir) + '/data/juz13'+ "Terminos_por_Rubro_1212181052.xlsx")
ls_terminos = ls_terminos['terminos']
ls_terminos = ls_terminos.append(pd.Series(['gast farmaceut', 'dan material']), ignore_index=True)

# %% [markdown]
# Cargamos documento con montos para test

# %%
montos_asign = pd.read_excel(str(project_dir) + '/data/input/'+ "Asignacion_de_montos_PI_1212181053.xlsx", header=1)

# %%
montos_asign.shape
# Out:
# (98, 68)

# %%
montos_asign.columns = proc_text(pd.Series(montos_asign.columns.values.tolist())).tolist()
montos_asign.columns
# Out:
# Index(['expedient', 'tip estructur', 'respons', 'total', 'valor vid',
#        'reparacion rod', 'dan emergent', 'dan rod', 'gast medic',
#        'gast atencion medic farmaci', 'lucr cesant', 'gast tratamient',
#        'incapac sobrevinient', 'dan motovehicul', 'reparacion automotor',
#        'privacion uso', 'dan moral', 'gast terapeut', 'dan fisic',
#        'incapac dan fisicolesion', 'incapac', 'dan motociclet',
#        'incapac sobrevinient', 'incapac sobrevinient psicofis',
#        'tratamient psicolog', 'gast tratamient farmaci', 'gast medic trasl',
#        'trasl', 'gast', 'dan material', 'gast futur', 'desvalorizacion',
#        'gast atencion medic trasl medicament estudi complementari',
#        'tratamient gast futur', 'gast tratamient psicolog kinesiolog',
#        'incapac fisic', 'tratamient kines', 'dan psicolog', 'dan patrimonial',
#        'dan extrapatrimonial', 'gast farmaci medic asistencial',
#        'tratamient psicolog kines', 'gast farmaci movil',
#        'gast farmaci estudi complementari asistent medic trasl',
#        'reintegr gast gast farmaci radiografi asistent medic',
#        'incapac psicofis tratamient kinesiolog psicolog', 'gast vestiment',
#        'dan incapac pas', 'dan incapac futur', 'tratamient medic psicolog',
#        'incapac psicolog', 'tratamient kinesiolog futur',
#        'tratamient psicoterapeut', 'gast honorari', 'honorari 1', 'honorari 2',
#        'honorari 3', 'honorari 4', 'honorari 5', 'honorari 6', 'honorari 7',
#        'honorari 8', 'honorari 9', 'honorari 10', 'honorari 11', 'honorari 12',
#        'honorari 13', 'honorari 14'],
#       dtype='object')

# %%
montos_asign.dropna(subset=['expedient'], inplace=True)
montos_asign.reset_index(drop=True,inplace=True)

# %%
montos_asign.shape
# Out:
# (92, 68)

# %%
montos_asign['rubros_values'] = np.nan
montos_asign['montos_values'] = np.nan

for i in range(len(montos_asign)):
    monto_tmp = montos_asign.loc[i].dropna().to_frame(name='monto')
    rubros_tmp = monto_tmp.index

    montos_asign.loc[i,'monto_values'] = [dict({'monto_asign': list(monto_tmp.monto)})]
    montos_asign.loc[i,'rubro_values'] = [dict({'rubro_asign': list(monto_tmp.index)})]

# %%
montos_asign.rubro_values
# Out:
# 0     {'rubro_asign': ['expedient', 'tip estructur', 'reparacion automotor', 'privacion uso', 'dan moral', 'gast terapeut']}
# 1     {'rubro_asign': ['expedient', 'tip estructur', 'dan moral', 'incapac sobrevinient']}
# 2     {'rubro_asign': ['expedient', 'privacion uso', 'dan moral', 'incapac sobrevinient', 'tratamient psicolog', 'gast', 'dan material']}
# 3     {'rubro_asign': ['expedient', 'dan moral', 'incapac sobrevinient', 'gast medic trasl', 'gast futur']}
# 4     {'rubro_asign': ['expedient', 'privacion uso', 'dan moral', 'incapac sobrevinient psicofis', 'dan material', 'desvalorizacion', 'gast atencion medic trasl medicament estudi complementari', 'tratamient gast futur', 'honorari 1', 'honorari 2', 'honorari 3', 'honorari 4', 'honorari 5', 'honorari 6']}
# 5     {'rubro_asign': ['expedient', 'privacion uso', 'dan moral', 'incapac', 'dan motociclet', 'gast tratamient psicolog kinesiolog']}
# 6     {'rubro_asign': ['expedient', 'incapac sobrevinient', 'tratamient psicolog', 'dan material', 'incapac fisic', 'tratamient kines', 'dan psicolog', 'dan extrapatrimonial', 'gast farmaci medic asistencial']}
# 7     {'rubro_asign': ['expedient', 'reparacion automotor', 'privacion uso', 'dan moral', 'incapac sobrevinient', 'tratamient psicolog kines', 'gast farmaci movil']}
# 8     {'rubro_asign': ['expedient', 'gast medic', 'gast tratamient', 'incapac sobrevinient', 'dan motovehicul', 'privacion uso', 'dan moral']}
# 9     {'rubro_asign': ['expedient', 'dan moral', 'dan fisic', 'tratamient psicolog', 'gast farmaci estudi complementari asistent medic trasl']}
# 10    {'rubro_asign': ['expedient', 'reparacion automotor', 'privacion uso', 'dan moral', 'dan fisic', 'trasl', 'gast futur', 'desvalorizacion', 'dan psicolog', 'reintegr gast gast farmaci radiografi asistent medic']}
# 11    {'rubro_asign': ['expedient', 'dan fisic']}
# 12    {'rubro_asign': ['expedient', 'respons', 'gast medic', 'dan moral', 'dan patrimonial']}
# 13    {'rubro_asign': ['expedient', 'respons', 'dan moral', 'trasl', 'gast farmaci medic asistencial', 'incapac psicofis tratamient kinesiolog psicolog', 'honorari 1', 'honorari 2', 'honorari 3', 'honorari 4', 'honorari 5', 'honorari 6', 'honorari 7', 'honorari 8', 'honorari 9']}
# 14    {'rubro_asign': ['expedient', 'respons', 'honorari 2', 'honorari 3', 'honorari 4', 'honorari 5', 'honorari 6', 'honorari 7']}
# 15    {'rubro_asign': ['expedient', 'respons', 'dan moral', 'incapac sobrevinient', 'tratamient psicolog', 'trasl']}
# 16    {'rubro_asign': ['expedient', 'respons', 'reparacion automotor', 'privacion uso', 'dan moral', 'incapac sobrevinient', 'dan psicolog', 'gast farmaci medic asistencial']}
# 17    {'rubro_asign': ['expedient', 'respons', 'honorari 1', 'honorari 2', 'honorari 3', 'honorari 4', 'honorari 5']}
# 18    {'rubro_asign': ['expedient', 'respons', 'gast medic', 'privacion uso', 'dan moral', 'dan material', 'incapac psicofis tratamient kinesiolog psicolog', 'gast vestiment']}
# 19    {'rubro_asign': ['expedient', 'respons', 'dan motovehicul', 'privacion uso', 'dan moral', 'incapac fisic']}
# 20    {'rubro_asign': ['expedient', 'respons', 'total', 'gast tratamient', 'incapac sobrevinient', 'dan moral', 'trasl', 'honorari 1', 'honorari 2', 'honorari 3', 'honorari 4', 'honorari 5', 'honorari 6']}
# 21    {'rubro_asign': ['expedient', 'respons', 'total', 'lucr cesant', 'incapac sobrevinient', 'reparacion automotor', 'privacion uso', 'dan moral', 'gast tratamient farmaci']}
# 22    {'rubro_asign': ['expedient', 'respons', 'total', 'incapac sobrevinient', 'reparacion automotor', 'privacion uso', 'dan moral', 'gast medic trasl', 'tratamient gast futur', 'honorari 1', 'honorari 2', 'honorari 3', 'honorari 4', 'honorari 5', 'honorari 6', 'honorari 7']}
# 23    {'rubro_asign': ['expedient', 'respons', 'lucr cesant', 'dan motovehicul', 'dan moral', 'incapac sobrevinient', 'gast farmaci medic asistencial', 'honorari 1', 'honorari 2', 'honorari 3', 'honorari 4', 'honorari 5', 'honorari 6']}
# 24    {'rubro_asign': ['expedient', 'respons', 'gast medic', 'dan moral', 'dan psicolog', 'honorari 1', 'honorari 2', 'honorari 3', 'honorari 4', 'honorari 5', 'honorari 6']}
# 25    {'rubro_asign': ['expedient', 'respons', 'dan moral', 'dan motociclet', 'gast farmaci medic asistencial', 'dan incapac pas', 'dan incapac futur', 'tratamient medic psicolog', 'honorari 1', 'honorari 2', 'honorari 3', 'honorari 4', 'honorari 5', 'honorari 6', 'honorari 7', 'honorari 8', 'honorari 9', 'honorari 10', 'honorari 11']}
# 26    {'rubro_asign': ['expedient', 'respons', 'gast medic', 'privacion uso', 'dan fisic', 'dan motociclet', 'tratamient psicolog', 'dan extrapatrimonial', 'incapac psicolog']}
# 27    {'rubro_asign': ['expedient', 'respons', 'honorari 1', 'honorari 2', 'honorari 3', 'honorari 4']}
# 28    {'rubro_asign': ['expedient', 'respons', 'total', 'honorari 1', 'honorari 2', 'honorari 3', 'honorari 4', 'honorari 5', 'honorari 6', 'honorari 7', 'honorari 8', 'honorari 9', 'honorari 10', 'honorari 11', 'honorari 12', 'honorari 13', 'honorari 14']}
# 29    {'rubro_asign': ['expedient', 'respons', 'total', 'incapac sobrevinient', 'dan moral', 'tratamient psicolog', 'gast']}
#                                                                ...
# 62    {'rubro_asign': ['expedient', 'respons', 'incapac sobrevinient', 'dan moral', 'gast terapeut', 'trasl', 'honorari 1', 'honorari 2', 'honorari 3', 'honorari 4', 'honorari 5', 'honorari 6']}
# 63    {'rubro_asign': ['expedient', 'respons', 'gast medic', 'incapac sobrevinient', 'dan moral', 'incapac sobrevinient psicofis', 'tratamient psicolog']}
# 64    {'rubro_asign': ['expedient', 'respons', 'incapac sobrevinient', 'gast honorari', 'honorari 1', 'honorari 2', 'honorari 3', 'honorari 4', 'honorari 5', 'honorari 6']}
# 65    {'rubro_asign': ['expedient', 'respons', 'total', 'incapac sobrevinient', 'reparacion automotor', 'privacion uso', 'dan moral', 'tratamient psicolog', 'gast tratamient farmaci']}
# 66    {'rubro_asign': ['expedient', 'respons', 'gast medic', 'incapac sobrevinient', 'reparacion automotor', 'privacion uso', 'dan moral', 'tratamient kines']}
# 67    {'rubro_asign': ['expedient', 'respons', 'total', 'honorari 1', 'honorari 2', 'honorari 3', 'honorari 4', 'honorari 5']}
# 68    {'rubro_asign': ['expedient', 'respons', 'total', 'reparacion automotor', 'privacion uso', 'dan moral', 'gast terapeut']}
# 69    {'rubro_asign': ['expedient', 'respons', 'gast medic', 'gast tratamient', 'incapac sobrevinient', 'privacion uso', 'dan moral', 'dan material', 'dan psicolog', 'honorari 1', 'honorari 2', 'honorari 3', 'honorari 4', 'honorari 5']}
# 70    {'rubro_asign': ['expedient', 'respons', 'gast tratamient', 'incapac sobrevinient', 'reparacion automotor', 'privacion uso', 'dan moral', 'tratamient psicolog']}
# 71    {'rubro_asign': ['expedient', 'respons', 'dan moral', 'dan fisic', 'gast atencion medic trasl medicament estudi complementari', 'dan psicolog']}
# 72    {'rubro_asign': ['expedient', 'respons', 'total', 'incapac sobrevinient', 'reparacion automotor', 'dan moral', 'gast terapeut']}
# 73    {'rubro_asign': ['expedient', 'respons', 'total', 'gast tratamient', 'incapac sobrevinient', 'dan moral', 'tratamient psicolog', 'gast futur', 'honorari 1', 'honorari 2', 'honorari 3', 'honorari 4', 'honorari 5', 'honorari 6', 'honorari 7', 'honorari 8']}
# 74    {'rubro_asign': ['expedient', 'respons', 'total', 'gast tratamient', 'incapac sobrevinient', 'dan moral', 'honorari 1', 'honorari 2', 'honorari 3', 'honorari 4', 'honorari 5', 'honorari 6', 'honorari 7']}
# 75    {'rubro_asign': ['expedient', 'respons', 'total', 'gast tratamient', 'incapac sobrevinient', 'reparacion automotor', 'privacion uso', 'dan moral', 'tratamient psicolog', 'gast tratamient psicolog kinesiolog', 'honorari 1', 'honorari 2', 'honorari 3', 'honorari 4', 'honorari 5', 'honorari 6', 'honorari 7']}
# 76    {'rubro_asign': ['expedient', 'respons', 'total', 'honorari 1', 'honorari 2', 'honorari 3']}
# 77    {'rubro_asign': ['expedient', 'respons', 'total', 'gast tratamient', 'incapac sobrevinient', 'dan moral', 'tratamient psicolog', 'honorari 1', 'honorari 2', 'honorari 3', 'honorari 4', 'honorari 5', 'honorari 6']}
# 78    {'rubro_asign': ['expedient', 'respons', 'incapac sobrevinient', 'dan moral', 'tratamient psicolog', 'gast atencion medic trasl medicament estudi complementari', 'tratamient kinesiolog futur', 'honorari 1', 'honorari 2', 'honorari 3', 'honorari 4', 'honorari 5']}
# 79    {'rubro_asign': ['expedient', 'respons', 'incapac sobrevinient', 'dan moral', 'gast', 'dan psicolog']}
# 80    {'rubro_asign': ['expedient', 'respons', 'gast medic', 'incapac sobrevinient']}
# 81    {'rubro_asign': ['expedient', 'respons', 'gast medic', 'gast tratamient', 'incapac sobrevinient', 'privacion uso', 'dan moral', 'dan material', 'honorari 1', 'honorari 2', 'honorari 3', 'honorari 4', 'honorari 5', 'honorari 6', 'honorari 7', 'honorari 8']}
# 82    {'rubro_asign': ['expedient', 'respons', 'honorari 1', 'honorari 2', 'honorari 3', 'honorari 4', 'honorari 5', 'honorari 6', 'honorari 7', 'honorari 8', 'honorari 9']}
# 83    {'rubro_asign': ['expedient', 'respons', 'incapac sobrevinient', 'dan moral', 'gast medic trasl', 'tratamient psicoterapeut']}
# 84    {'rubro_asign': ['expedient', 'respons', 'gast medic', 'incapac sobrevinient', 'dan moral', 'honorari 1', 'honorari 2', 'honorari 3', 'honorari 4']}
# 85    {'rubro_asign': ['expedient', 'respons', 'gast medic', 'incapac sobrevinient', 'honorari 1', 'honorari 2', 'honorari 3', 'honorari 4', 'honorari 5', 'honorari 6']}
# 86    {'rubro_asign': ['expedient', 'respons', 'honorari 1', 'honorari 2', 'honorari 3', 'honorari 4', 'honorari 5']}
# 87    {'rubro_asign': ['expedient', 'respons']}
# 88    {'rubro_asign': ['expedient', 'respons', 'dan emergent', 'incapac sobrevinient', 'dan moral', 'honorari 1', 'honorari 2', 'honorari 3']}
# 89    {'rubro_asign': ['expedient', 'respons', 'incapac sobrevinient', 'dan moral', 'honorari 1', 'honorari 2', 'honorari 3', 'honorari 4', 'honorari 5', 'honorari 6', 'honorari 7']}
# 90    {'rubro_asign': ['expedient', 'respons', 'honorari 1', 'honorari 2', 'honorari 3', 'honorari 4']}
# 91    {'rubro_asign': ['expedient', 'respons']}
# Name: rubro_values, Length: 92, dtype: object

# %% [markdown]
# ## 1. Procesamiento de Fallo y Lista de Rubros

# %% [markdown]
# Procesamos rubros

# %%
FalloTK = bsp.bp_token(proc_text(df.text))
FalloNorm = proc_text(df.text)

# %%
FalloNorm_df = FalloNorm.to_frame()
FalloNorm_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1189 entries, 0 to 1188
# Data columns (total 1 columns):
# text    1189 non-null object
# dtypes: object(1)
# memory usage: 9.4+ KB

# %% [markdown]
# Procesamos lista de terminos

# %%
ls_terminos = proc_text(ls_terminos.dropna())

# %% [markdown]
# ## 2. Indexacion de ngrama por palabra clave

# %% [markdown]
# ### 2.1 Generacion de ngramas

# %%
FalloNorm_df['gram2'] = np.nan
def get_ngrams(text, n ):
    n_grams = ngrams(word_tokenize(text), n)
    return [ ' '.join(grams) for grams in n_grams]

listvalues = get_ngrams(FalloNorm_df.text[3], 2 )
listvalues1gram = get_ngrams(FalloNorm_df.text[3], 1)

# %% [markdown]
# ### 2.2 Obtención de posición en ngramas

# %%
# Creamos un dataframe dummy
df_rubros = pd.DataFrame([])

def ngram_index(ngramselect, listvalues):
    # Extrae index de posiciones de ngram
    # output: lista de indices de ngrama especifico
    get_indexes = lambda x, xs: [i for (y, i) in zip(xs, range(len(xs))) if x == y]
    lista = get_indexes(ngramselect, listvalues)
    return(lista)

for gram in ls_terminos:
    # recorre la lista de terminos y asocia las posiciones máximas a los ngram 
    # específicos
    
    lsindex = ngram_index(gram, listvalues)
    
    if len(lsindex) != 0:
        tmp_in = pd.DataFrame(np.array([str(gram), str(max(lsindex))]).reshape(1,2), columns = ['rubro','maxindex'])
        df_rubros = df_rubros.append(tmp_in)

# %% [markdown]
# ### 2.3 Obtención de la posición de los montos

# %% [markdown]
# Primero extraemos las posiciones de los montos

# %%
index_amount = list(ngram_index('$', listvalues1gram))
size_amount = list(listvalues1gram[x+1] for x in ngram_index('$', listvalues1gram))

# %% [markdown]
# Asignamos las posiciones a los montos correspondientes

# %%
df_amount = pd.DataFrame({'index_amount': index_amount, 'size_amount': size_amount})

# %%
df_amount
# Out:
#     index_amount size_amount
# 0   170           172
# 1   174           350000
# 2   178           100000
# 3   182           80000
# 4   186           80000
# 5   192           2500
# 6   198           612672
# 7   3835          80
# 8   3837          120
# 9   4626          800
# 10  4677          120000
# 11  4680          2400
# 12  4901          200
# 13  4973          90000
# 14  4976          19200
# 15  5277          80000
# 16  5376          2500
# 17  5939          172
# 18  5994          172
# 19  6016          314272
# 20  7950          314272

# %%
df_rubros
# Out:
#                       rubro maxindex
# 0  dan fisic                 172
# 0  incapac fisic             7801
# 0  incapac sobrevinient      5549
# 0  dan estet                 5621
# 0  lesion estet              5594
# 0  lesion estet              5594
# 0  dan moral                 5052
# 0  dan extrapatrimonial      7805
# 0  agravi moral              5445
# 0  dan patrimonial           5422
# 0  agravi moral              5445
# 0  perd chanc                4229
# 0  lucr cesant               2812
# 0  gast medic                188
# 0  gast farmaci              7761
# 0  dan material              7765
# 0  gast futur                5732
# 0  tratamient psicoterapeut  5828
# 0  dan estet                 5621
# 0  dan extrapatrimonial      7805
# 0  consecuent patrimonial    5528
# 0  tratamient kines          5735
# 0  incapac fisic             7801
# 0  grad incapac              5498
# 0  indemnizacion incapac     4078
# 0  medic farmaci             189
# 0  gast farmaci              7761
# 0  tratamient psicoterapeut  5828
# 0  realizacion tratamient    5901
# 0  exam fisic                3604
# 0  gast medic                188
# 0  atencion medic            3886
# 0  lesion padec              3816
# 0  indol lesion              5297
# 0  lesion sentimient         4990
# 0  lesion estet              5594
# 0  consecuent lesion         2689
# 0  lesion derech             2694
# 0  sufr lesion               546
# 0  import lesion             164
# 0  desvalorizacion rod       7883
# 0  perd valor                7532
# 0  dan material              7765
# 0  dan patrimonial           5422
# 0  dan person                2546
# 0  dan emergent              3440
# 0  vid util                  4177
# 0  fij indemnizacion         5619
# 0  mont indemnizacion        5152
# 0  merm patrimonial          4711
# 0  dan material              7765

# %% [markdown]
# ## 2.4 Medida de distancia entre index

# %%
def takeClosest(myList, myNumber):
    """
    Asume una lista ordenada.

    Si dos numeros son igualmente cercanos, trae el menor.
    """
    pos = bisect_left(myList, myNumber)
    if pos == 0:
        return myList[0]
    if pos == len(myList):
        return myList[-1]
    before = myList[pos - 1]
    after = myList[pos]
    if after - myNumber < myNumber - before:
       return after
    else:
       return before

# %% [markdown]
# ## 2.5 Asignación de Montos a rubros

# %%
df_rubro_monto = pd.DataFrame([])

for rubro_index in df_rubros.maxindex:
    
    # Select index amount near to rubro index
    amount_select = takeClosest(df_amount.index_amount, int(rubro_index))
    
    # select amount
    amount = df_amount[df_amount.index_amount == amount_select]['size_amount']
    
    # select rubro
    rubro = df_rubros[df_rubros.maxindex == rubro_index]['rubro']
    
    tmp_in = pd.DataFrame(np.array([rubro.iloc[0], amount.iloc[0]]).reshape(1,2), columns = ['rubro','monto'])
    df_rubro_monto = df_rubro_monto.append(tmp_in)
    
    # merge

# %%
df_rubro_monto
# Out:
#                       rubro   monto
# 0  dan fisic                 172
# 0  incapac fisic             314272
# 0  incapac sobrevinient      2500
# 0  dan estet                 2500
# 0  lesion estet              2500
# 0  lesion estet              2500
# 0  dan moral                 19200
# 0  dan extrapatrimonial      314272
# 0  agravi moral              2500
# 0  dan patrimonial           2500
# 0  agravi moral              2500
# 0  perd chanc                120
# 0  lucr cesant               80
# 0  gast medic                80000
# 0  gast farmaci              314272
# 0  dan material              314272
# 0  gast futur                172
# 0  tratamient psicoterapeut  172
# 0  dan estet                 2500
# 0  dan extrapatrimonial      314272
# 0  consecuent patrimonial    2500
# 0  tratamient kines          172
# 0  incapac fisic             314272
# 0  grad incapac              2500
# 0  indemnizacion incapac     120
# 0  medic farmaci             80000
# 0  gast farmaci              314272
# 0  tratamient psicoterapeut  172
# 0  realizacion tratamient    172
# 0  exam fisic                80
# 0  gast medic                80000
# 0  atencion medic            120
# 0  lesion padec              80
# 0  indol lesion              80000
# 0  lesion sentimient         19200
# 0  lesion estet              2500
# 0  consecuent lesion         80
# 0  lesion derech             80
# 0  sufr lesion               612672
# 0  import lesion             172
# 0  desvalorizacion rod       314272
# 0  perd valor                314272
# 0  dan material              314272
# 0  dan patrimonial           2500
# 0  dan person                80
# 0  dan emergent              80
# 0  vid util                  120
# 0  fij indemnizacion         2500
# 0  mont indemnizacion        80000
# 0  merm patrimonial          2400
# 0  dan material              314272

# %% [markdown]
# ## 3. Generalizacion de NGram

# %% [markdown]
# ## Funciones

# %%
def ngram_index(ngramselect, listvalues):
    # Extrae index de posiciones de ngram
    # output: lista de indices de ngrama especifico
    get_indexes = lambda x, xs: [i for (y, i) in zip(xs, range(len(xs))) if x == y]
    lista = get_indexes(ngramselect, listvalues)
    return(lista)

df_rubros = pd.DataFrame([])

# %% [markdown]
# ### 3.1 Generamos los 1gram y 2gram

# %%
FalloNorm_df['gram2'] = FalloNorm_df['text'].apply(lambda x:  get_ngrams(str(x), 2))
FalloNorm_df['gram1'] = FalloNorm_df['text'].apply(lambda x:  get_ngrams(str(x), 1))
# Out:
# /anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:4: DeprecationWarning: generator 'ngrams' raised StopIteration
#   after removing the cwd from sys.path.

# %% [markdown]
# ### 3.2 Obtención de index Ngram

# %%
FalloNorm_df['rubros'] = np.nan
FalloNorm_df['index_rubros'] = np.nan
FalloNorm_df['montos'] = np.nan
FalloNorm_df['index_montos'] = np.nan

# %%
df_rubros = pd.Series([])

# %%
i = 0

# recorremos todos los documentos
for j in range(len(FalloNorm_df)-1):
    
    # Extraigo los ngramas
    text2gram = FalloNorm_df['gram2'][i]
    text1gram = FalloNorm_df['gram1'][i]
    
    df_rubros = pd.DataFrame([])
    
    for gram in ls_terminos:
        # recorre la lista de terminos y asocia las posiciones máximas a los ngram 
        # específicos
        
        # Extraemos los index de los ngramas de tipo 2
        lsindex = ngram_index(gram, text2gram)
        
        # Si no captura ngramas salta
        if len(lsindex) != 0:
            
            tmp_in = pd.DataFrame(np.array([str(gram), str(max(lsindex))]).reshape(1,2), 
                                  columns = ['rubro','maxindex'])
            
            df_rubros = df_rubros.append(tmp_in)
    
    # Guardamos los rubros, montos e indices de cada registro
    FalloNorm_df.loc[i,'rubros'] = [dict({'rubros': list(df_rubros.rubro)})]
    FalloNorm_df.loc[i,'index_rubros'] = [dict({'rubros': list(df_rubros.maxindex)})]
    FalloNorm_df.loc[i, 'montos'] = [dict({'montos': list(text1gram[x+1] for x in ngram_index('$', text1gram))})]
    FalloNorm_df.loc[i, 'index_montos'] = [dict({'index_montos': list(ngram_index('$', text1gram))})]
    
    # Extraigo los indices y montos
    index_amount = list(ngram_index('$', text1gram))
    size_amount = list(text1gram[x+1] for x in ngram_index('$', text1gram))
    
    # reseteo el dataframe de rubros
    df_rubro_monto = pd.DataFrame([])
   
    # Construimos un dataframe intermedio
    df_amount = pd.DataFrame({'index_amount': index_amount, 'size_amount': size_amount})
    
    print('Registro Nro {}'.format(str(i)))
    
    for rubro_index in df_rubros.maxindex:

        # Select index amount near to rubro index
        amount_select = takeClosest(list(df_amount.index_amount), int(rubro_index))

        # select amount
        amount = df_amount[df_amount.index_amount == amount_select]['size_amount']

        # select rubro
        rubro = df_rubros[df_rubros.maxindex == rubro_index]['rubro']

        tmp_in = pd.DataFrame(np.array([rubro.iloc[0], amount.iloc[0]]).reshape(1,2), columns = ['rubro','monto'])
        
        df_rubro_monto = df_rubro_monto.append(tmp_in)
        
    print('Rubro Procesado')
    
    print('---> {}'.format(df_rubro_monto.shape))
    
    FalloNorm_df.loc[i,'rubros_asign'] = [dict({'rubros_asign': list(df_rubro_monto.rubro)})]
    FalloNorm_df.loc[i,'monto_asign'] = [dict({'monto_asign': list(df_rubro_monto.monto)})]
    
    print('Rubro Procesado stored')
    i+=1
# Out:
# Registro Nro 0
# Rubro Procesado
# ---> (1, 2)
# Rubro Procesado stored
# Registro Nro 1
# Rubro Procesado
# ---> (1, 2)
# Rubro Procesado stored
# Registro Nro 2
# Rubro Procesado
# ---> (1, 2)
# Rubro Procesado stored
# Registro Nro 3
# Rubro Procesado
# ---> (2, 2)
# Rubro Procesado stored
# Registro Nro 4
# Rubro Procesado
# ---> (1, 2)
# Rubro Procesado stored
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-265-b0ed4ef18874> in <module>
#      26
#      27     # Guardamos los rubros, montos e indices de cada registro
# ---> 28     FalloNorm_df.loc[i,'rubros'] = [dict({'rubros': list(df_rubros.rubro)})]
#      29     FalloNorm_df.loc[i,'index_rubros'] = [dict({'rubros': list(df_rubros.maxindex)})]
#      30     FalloNorm_df.loc[i, 'montos'] = [dict({'montos': list(text1gram[x+1] for x in ngram_index('$', text1gram))})]
#
# /anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'rubro'
